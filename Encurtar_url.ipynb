# %% [markdown]
# <a href="https://colab.research.google.com/github/aldinodemetrio-ai/Materiais_Alunos_EAD/blob/main/Encurtar_url.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyshorteners
import pyshorteners


url = "https://drive.google.com/file/d/10BKaHsgK5KXYDEQPP2E6nmHKpV3fmxRd/view?usp=sharing"


s = pyshorteners.Shortener()
url_curta = s.tinyurl.short(url)

print(url_curta)
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyshorteners: filename=pyshorteners-1.0.1-py3-none-any.whl size=17479 sha256=cfa4c77c6b0f29a2da6d7a3f613415b2f7ebcbb634d2f4b6df2ca7712a2d879c
#   Stored in directory: /root/.cache/pip/wheels/30/e9/7c/06d5ea1c320274f44cc35321a75198e266b2d47b3092aa9b7e
# Successfully built pyshorteners
# ...
# https://tinyurl.com/2aum376t

# %%
import pyshorteners

url = "https://drive.google.com/file/d/190OfbNW-iza7UeOR3bYsQJ_ZugB6w4M1/view?usp=drive_link"


s = pyshorteners.Shortener()
url_curta = s.tinyurl.short(url)

print(url_curta)
# Out:
# https://tinyurl.com/25clr5u7
